# %% [markdown]
# <a href="https://colab.research.google.com/github/glizcano571/PROG_COMB/blob/main/POO_Introducci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
color_techo="Blanco con borde amarillo y borde rosado"
color_pared="Blanca con bordes amarillos y bordes rosados"
cant_ventanas=3
cant_puertas=1
cant_pisos=1
cant_baños=1
color_marco_ventanas="Amarillo y rosado"
decoración_flores=True
flores_decoración="Hojas y flores"
letrero=False
graffiti=False
dibujo_graffiti="Diablito y Homero"

# %%
def decorando_floristeria(a,b,c,d,e,f,g,h,letrero,graffiti):
  color_techo=a
  color_pared=b
  cant_ventanas=c
  cant_puertas=d
  cant_pisos=e
  cant_baños=f
  color_marco_ventanas=g
  decoración_flores=h
  if h:flores_decoración=input("Ingrese las flores con las que decoró el edificio")
  if letrero: nombre_letrero=input("Cuál es el nombre de la floristería")
  if graffiti: dibujo_graffiti=input("Qué dibujo pintaste?")
  print(f"Descripción de mi floristería: \nEl color del techo es {a}, \nEl color de la pared es {b}, \nLa cantidad de ventanas es {c}, \nLa cantidad de puertas es {d}, La cantidad de pisos es {e}, \nLa cantidad de baños es {f}, \nEl color del marco de la ventana es {g}, \n¿Tiene decoración de flores? {h},\n¿Qué flores tiene? {flores_decoración}, \n¿Tiene letrero? {letrero}, \n¿Tiene graffiti? {graffiti}")

# %%
decorando_floristeria("Blanco con borde amarillo y borde rosado", "Blanca con bordes amarillos y bordes rosados", 3, 1, 1, 1, "Amarillo y rosado", True, "", "")
# Out:
# Ingrese las flores con las que decoró el edificioHojas y flores bonitas
# Descripción de mi floristería:
# El color del techo es Blanco con borde amarillo y borde rosado,
# El color de la pared es Blanca con bordes amarillos y bordes rosados,
# La cantidad de ventanas es 3,
# La cantidad de puertas es 1, La cantidad de pisos es 1,
# La cantidad de baños es 1,
# El color del marco de la ventana es Amarillo y rosado,
# ¿Tiene decoración de flores? True,
# ¿Qué flores tiene? Hojas y flores bonitas
# ¿Tiene letrero? ,
# ¿Tiene graffiti?
