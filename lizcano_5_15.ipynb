# %% [markdown]
# <a href="https://colab.research.google.com/github/glizcano571/PROG_COMB/blob/main/lizcano_5_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %% [markdown]
# ##  6. Desarrolla un programa que determine si un número es par o impar.

# %%
num=float(input("Ingrese el número: "))
if num % 2==0:
  print("El número es par")
else:
  print("El número es impar")
# Out:
# Ingrese el número: 9
# El número es impar

# %%
num=float(input("Ingrese el número: "))
"El número es par" if num % 2==0 else "El número es impar"
# Out:
# Ingrese el número: 9
# 'El número es impar'

# %% [markdown]
# ##  7. Crea un programa que determine si un año es bisiesto (divisible por 4 y no por 100, o divisible por 400).

# %%
año=float(input("Ingrese el año: "))
if (año % 4 == 0 and año % 100 != 0) or (año % 400 == 0):
  print("El año es bisiesto")
else:
  print("El año no es bisiesto")
# Out:
# Ingrese el año: 90
# El año no es bisiesto

# %%
año=float(input("Ingrese el año: "))
print("El año es bisiesto" if (año % 4 == 0 and año % 100 != 0) or (año % 400 == 0) else "El año no es bisiesto")
# Out:
# Ingrese el año: 90
# El año no es bisiesto

# %% [markdown]
# ## 8. Escribe un programa que solicite el nombre del usuario y determine si una persona pertenece a la tercera edad (70 años o más) y si se cumple la condición, imprima que se le da prioridad en la fila.

# %%
nombre=input("Escriba su nombre: ")
edad=float(input("Escriba su edad: "))
if edad > 70:
  print("Tiene prioridad en la fila")
else:
    print("No tiene prioridad en la fila")
# Out:
# Escriba su nombre: andres
# Escriba su edad: 3
# No tiene prioridad en la fila

# %%
nombre=input("Escriba su nombre: ")
edad=float(input("Escriba su edad: "))
print("Tiene prioridad en la fila" if edad > 70 else "No tiene prioridad en la fila")

# %% [markdown]
# ##  9. Desarrolla un programa que compare tres números y muestre el mayor.

# %%
num1 = float(input("Ingrese el primer número: "))
num2 = float(input("Ingrese el segundo número: "))
num3 = float(input("Ingrese el tercer número: "))
if num1 >= num2 and num1 >= num3:
    mayor = num1
else:
  if num2 >= num1 and num2 >= num3:
    mayor = num2
  else:
    mayor = num3
print("El número mayor es:", mayor)

# %%
num1 = float(input("Ingrese el primer número: "))
num2 = float(input("Ingrese el segundo número: "))
num3 = float(input("Ingrese el tercer número: "))
if num1 >= num2 and num1 >= num3:
    mayor = num1
elif num2 >= num1 and num2 >= num3:
    mayor = num2
else:
    mayor = num3
print("El número mayor es:", mayor)

# %%
num1 = float(input("Ingrese el primer número: "))
num2 = float(input("Ingrese el segundo número: "))
num3 = float(input("Ingrese el tercer número: "))
mayor = num1 if num1 >= num2 and num1 >= num3 else num2 if num2 >= num1 and num2 >= num3 else num3
print("El número mayor es:", mayor)

# %% [markdown]
# ##10. Crea un programa que determine si un triángulo es equilátero, isósceles o escaleno según sus lados.

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 == lado2 and lado2 == lado3:
    tipo="Equilatero"
else:
  if lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
      tipo="Isósceles"
  else:
      tipo="Escaleno"
print("El tipo de triángulo que se forma es: ",tipo)

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 == lado2 and lado2 == lado3:
    tipo="Equilatero"
elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
      tipo="Isósceles"
else:
      tipo="Escaleno"
print("El tipo de triángulo que se forma es: ",tipo)

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
tipo="Equilatero" if lado1 == lado2 and lado2 == lado3 else "Isósceles" if lado1 == lado2 or lado1 == lado3 or lado2 == lado3 else "Escaleno"
print("El tipo de triángulo que se forma es: ",tipo)

# %% [markdown]
# ##11. Escribe un programa que calcule el índice de masa corporal (IMC) y determine la categoría (bajo peso, normal, sobrepeso, obesidad). Al final, el programa debe imprimir: el nombre del usuario, su categoría y una breve descripción de lo que debe hacer de acuerdo a su categoría.

# %%
nombre=input("¿Cuál es su nombre?: ")
peso=float(input("¿Cuánto pesas?: "))
estatura=float(input("¿Cuánto mides?: "))
imc= peso/(estatura*estatura)
if imc<18.5:
  categoría= "Bajo peso"
  descripción= "Debes comer más"
else:
  if imc>=18.5 and imc<=24.9:
    categoría= "Normal"
    descripción= "Mantente así"
  else:
      if imc>=25 and imc<=29.9:
        categoría= "Sobrepeso"
        descripción= "Debes regular tu alimentación"
      else:
        if imc>=30:
          categoría= "Obesidad"
          descripción= "Ve al médico, cuida de tu salúd"

print("Su nombre es: ",nombre)
print("Su categoría es: ",categoría)
print("Descripción: ",descripción)

# %%
nombre=input("¿Cuál es su nombre?: ")
peso=float(input("¿Cuánto pesas?: "))
estatura=float(input("¿Cuánto mides?: "))
imc= peso/(estatura*estatura)
if imc<18.5:
  categoría= "Bajo peso"
  descripción= "Debes comer más"
elif imc>=18.5 and imc<=24.9:
    categoría= "Normal"
    descripción= "No necesitas hacer nada"
elif imc>=25 and imc<=29.9:
    categoría= "Sobrepeso"
    descripción= "Debes alimentarte mejor"
else:
  categoría= "Obesidad"
  descripción= "Ve al médico, protege tu salúd"

print("Su nombre es: ",nombre)
print("Su categoría es: ",categoría)
print("Descripción: ",descripción)

# %%
nombre=input("¿Cuál es su nombre?: ")
peso=float(input("¿Cuánto pesas?: "))
estatura=float(input("¿Cuánto mides?: "))
imc= peso/(estatura*estatura)
Categoría= "Bajo peso" if imc<18.5 else "Normal" if imc>=18.5 and imc<=24.9 else "Sobrepeso" if imc>=25 and imc<=29.9 else "Obesidad"
Descripcipción= "Debes comer más" if imc<18.5 else "No necesitas hacer nada" if imc>=18.5 and imc<=24.9 else "Debes alimentarte mejor" if imc>=25 and imc<=29.9 else "Ve al médico, protege tu salúd"
print("Su nombre es: ",nombre)
print("Su categoría es: ",categoría)
print("Descripción: ",descripción)

# %% [markdown]
# ##  12. Desarrolla un programa que simule una calculadora simple (+, -, *, /) con dos números.

# %%
num1=float(input("Ingrese el primer número"))
num2=float(input("Ingrese el segundo número"))
op=input("¿Qué operación quiere realizar entre esos dos números? (+, -, *, /)")
if op == "+" :
  resultado=num1+num2
else:
    if op == "-" :
      resultado=num1-num2
    else:
        if op == "*" :
          resultado=num1*num2
        else:
          resultado=num1/num2
print("Resultado: ",resultado)

# %%
num1=float(input("Ingrese el primer número"))
num2=float(input("Ingrese el segundo número"))
op=input("¿Qué operación quiere realizar entre los números? (+, -, *, /)")
if op == "+" :
  resultado=num1+num2
elif op == "-" :
      resultado=num1-num2
elif op == "*" :
          resultado=num1*num2
else:
          resultado=num1/num2
print("Resultado: ",resultado)

# %%
num1=float(input("Ingrese el primer número"))
num2=float(input("Ingrese el segundo número"))
op=input("¿Qué operación quiere realizar entre los dos números? (+, -, *, /)")
resultado= num1+num2 if op == "+" else num1-num2 if op == "-" else num1*num2 if op == "*" else num1/num2
print("Resultado: ",resultado)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1241938085.py in <cell line: 0>()
# ----> 1 num1=float(input("Ingrese el primer número"))
#       2 num2=float(input("Ingrese el segundo número"))
#       3 op=input("¿Qué operación quiere realizar entre los dos números? (+, -, *, /)")
#       4 resultado= num1+num2 if op == "+" else num1-num2 if op == "-" else num1*num2 if op == "*" else num1/num2
#       5 print("Resultado: ",resultado)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ##  13. Crea un programa que determine la calificación en letras (A, B, C, D, F) según una nota numérica (0-100).

# %%
nota=float(input("Ingrese la nota (0-100): "))
if nota>90:
  calificacion= "A"
else:
  if nota > 80:
   calificacion= "B"
  else:
    if nota>60:
     calificacion= "C"
    else:
      if nota>40:
       calificacion= "D"
      else:
        calificacion= "F"
print("La calificación en letra es: ",calificacion)

# %%
nota=float(input("Ingrese la nota (0-100): "))
if nota>90:
  calificacion= "A"
elif nota > 80:
   calificacion= "B"
elif nota>60:
     calificacion= "C"
elif nota>40:
       calificacion= "D"
else:
        calificacion= "F"
print("La calificación en letra es: ",calificacion)

# %%
nota=float(input("Ingrese la nota (0-100): "))
calificación = "A" if nota>90 else "B" if nota>80 else "C" if nota>60 else "D" if nota>40 else "F"
print("La calificación en letra es: ",calificación)

# %% [markdown]
# ## 14. Escribe un programa que determine el día de la semana según un número (1-7).

# %%
dia=int(input("Escriba un número del 1 al 7 para descubrir que día de la semana es: "))
if dia == 1:
  d= "Domingo"
else:
  if dia == 2:
    d="Lunes"
  else:
    if dia == 3:
      d="Martes"
    else:
      if dia == 4:
        d="Miércoles"
      else:
        if dia == 5:
          d="Jueves"
        else:
          if dia == 6:
            d="Viernes"
          else:
            d="Sábado"
print("El día de la semana que corresponde a ese número es: ",d)

# %%
día=int(input("Escriba un número del 1 al 7 para descubrir que día de la semana es: "))
if dia == 1:
  d= "Domingo"
elif dia == 2:
    d="Lunes"
elif dia == 3:
      d="Martes"
elif dia == 4:
        d="Miércoles"
elif dia == 5:
          d="Jueves"
elif dia == 6:
            d="Viernes"
else:
            d="Sábado"
print("El día de la semana que corresponde a ese número es: ",d)

# %%
dia=int(input("Escriba un número del 1 al 7 para descubrir que día de la semana es: "))
d= "Domingo" if dia == 1 else "Lunes" if dia == 2 else "Martes" if dia == 3 else "Miércoles" if dia == 4 else "Jueves" if dia == 5 else "Viernes" if dia == 6 else "Sábado"
print("El día de la semana que corresponde a ese número es: ",d)

# %% [markdown]
# ##15. Desarrolla un programa que valide si tres números pueden formar un triángulo y de qué tipo es.

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado2 + lado3 > lado1:

  if lado1 == lado2 and lado2 == lado3:
    tipo="Equilatero"
  else:
    if lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
      tipo="Isósceles"
    else:
      tipo="Escaleno"

    print("Sí pueden formar un triángulo")
    print("El tipo de triángulo que se forma es: ",tipo)

else:
  print("No se puede formar un triángulo")

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado2 + lado3 > lado1:

  if lado1 == lado2 and lado2 == lado3:
    tipo="Equilatero"
  elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
      tipo="Isósceles"
  else:
      tipo="Escaleno"

  print("Sí pueden formar un triángulo")
  print("El tipo de triángulo que se forma es: ",tipo)

else:
  print("No se puede formar un triángulo")

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado2 + lado3 > lado1:
  tipo="Equilatero" if lado1 == lado2 and lado2 == lado3 else "Isósceles" if lado1 == lado2 or lado1 == lado3 or lado2 == lado3 else "Escaleno"
  print("Sí pueden formar un triángulo")
  print("El tipo de triángulo que se forma es: ",tipo)
else:
  print("No se puede formar un triángulo")
