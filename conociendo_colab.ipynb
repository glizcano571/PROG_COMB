# %% [markdown]
# #Título nivel 1
# ##título nivel 2
# ###Título nivel 3
#
# hola, cómo estás?
# 1. hola
# 2. cómo
# 3. estás
#
# * yo
# * muy
# * bien
#
# if (condición):
#   aquí va la condición si se cumple
# else:
#   aquí va si la condicion no se cumple
# ```
# # Tiene formato de código
#
# if (condición):
#   aquí va la condición si se cumple
# else:
#   aquí va si la condicion no se cumple
#
# ```

# %% [markdown]
# SALUDANDO AL MUNDO

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# ##INPUT
# Input, es una funcion que pemite ingresar datos.
#
# posee tres funciones
# 1. lee: se puede ingresar informacion
# 2. almacena: guarda la informacion en una variable (var)
# 3. Declara: todos los datos almacenados los vuelve string
#
# Sintaxis
#
#
# ```
# var=input(aqui va su impresion)
# ```
# si desea realizar una lectura de un tipo de dato diferente a string, se debe realizar una cinversion de datos.
# para ello coloque el tipo de dsto a convertir, y encierre el tipo original de dato en parentesis
#
#
#
# ```
# var=int(input()) #aqui se va a tramsformar un dato de string a entero
# var2=float(input()) # de string a decimal
# var3=bool(input()) # se transfroma de string a booleano
# ```

# %%
name= input("comó te llamas?")
# Out:
# comó te llamas?andres

# %%
edad1=int(input((f"cuantos años tienes,{name}?")))
# Out:
# cuantos años tienes,andres?18

# %%
edad2=int(input("edad del compañero de al lado?"))
# Out:
# edad del compañero de al lado?19

# %%
print(f"la suma de las dos edades es {edad1+edad2}")
# Out:
# la suma de las dos edades es 37
