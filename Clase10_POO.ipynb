# %% [markdown]
# <a href="https://colab.research.google.com/github/glizcano571/PROG_COMB/blob/main/Clase10_POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Programación orientada a objetos POO
# -Paradigma de programación enfocado en crear marcos (clase) que a su vez generan instancias (objetos).
# - Está fundamentada bajo 4 principios fundamentales o pilares: **Herencia, Abstracción, Polimorfismo y Encapsulamiento**
# - Ventajas al implementar POO
# 1. Escalabilidad: un mismo código en diferentes app.
# 2. Seguridad: No cualquier persona tiene acceso al código.
# 3. Modularidad: El código se expresa a partir de "pedazos" (métodos).
# 4. Reusabilidad: Se puede reutilizar partes del código en lugar de generar un código nuevo.
# 5. Mantenibilidad: El código puede ser fácilmente corregido y actualizado.

# %%
t_letrero=""
t_graffiti=""
color_techo=input("¿Cuál es el color del techo de la floristería?")
color_pared_trasera=input("¿Cuál es el color de la pared trasera de la floristería?")
color_pared_lado_derecho=input("¿Cuál es el color de la pared del lado derecho de la floristería?")
color_pared_lado_izquierdo=input("¿Cuál es el color de la pared del lado izquierdo de la floristería?")
cant_ventanas=int(input("¿Cuántas ventanas tiene tu floristería?"))
ventana_abierta=input("¿Tienes alguna ventana abierta?, (sí/no)")
if ventana_abierta == "sí":
  v_abierta="Abierta"
else:
  v_abierta="Cerrada"
cant_puertas=int(input("¿Cuántas puertas tiene tu floristería?"))
puerta_abierta=input("¿La puerta de tu floristería está abierta?, (sí/no)")
if puerta_abierta == "sí":
  p_abierta="Abierta"
else:
  p_abierta="Cerrada"
cant_pisos=int(input("¿Cuántos pisos tiene tu floristería?"))
cant_baños=int(input("¿Cuántos baños tiene tu floristería?"))
color_marco_ventanas=input("¿Tu floristería tiene color en el marco de las ventanas, (sí/no)?")
if color_marco_ventanas == "sí":
  color_m_ventanas=input("¿Cuál es el color del marco de tus ventanas?")
decoración_flores=input("¿Tu floristería tiene decoración de flores, (sí/no)?")
if decoración_flores == "sí":
  flores=input("¿Qué tipo de flores tiene?")
letrero=input("¿Tu floristería tiene letreros, (sí/no)?")
if letrero == "sí":
  t_letrero=input("¿Qué dice tu letrero?")
graffiti=input("¿Tu floristería tiene graffitis, (sí/no)?")
if graffiti == "sí":
  t_graffiti=input("¿Qué graffiti tiene tu floristería?")
cant_macetas=(input("¿ Tu floristería tiene macetas, (sí/no)?"))
if cant_macetas == "sí":
    c_macetas=input("¿Cuántas macetas hay en tu floristería?")
ubicación=input("¿En donde está ubicada tu floristería?")
cant_estantes=input("¿Tu floristería tiene estantes, (sí/no)?")
if cant_estantes =="sí":
  c_estantes=int(input("¿Cuántos estantes tiene tu floristería?"))

print("El color del techo de la floristería es:", color_techo)
if cant_macetas == "sí":
 print("Tu floristería tiene,", c_macetas, "cantidad de macetas")
print("Tu floristería está ubicada en:", ubicación)

if cant_estantes =="sí":
  print("La cantidad de estantes de tu floristería es:", c_estantes)
print("El color de la pared trasera de la floristería es:", color_pared_trasera)
print("El color de la pared del lado derecho de la floristería es:", color_pared_lado_derecho)
print("El color de la pared del lado izquierdo de la floristería es:", color_pared_lado_izquierdo)
print("La cantidad de ventanas que tiene la floristería es:", cant_ventanas)
if ventana_abierta == "sí":
  print("La ventana está: ", v_abierta)
else:
  print("La ventana está: ", v_abierta)
print("La cantidad de puertas que tiene la floristería es:", cant_puertas)
if puerta_abierta == "sí":
  print("La puerta de tu floristería está:", p_abierta)
else:
  print("La puerta de tu floristería está:", p_abierta)
print("La cantidad de pisos que tiene la floristería es:", cant_pisos)
print("La cantidad de baños que tiene la floristería es:", cant_baños)
if color_marco_ventanas == "sí":
 print("El color del marco de las ventanas de la floristería es:", color_m_ventanas)
if decoración_flores == "sí":
 print("El tipo de flores que tiene la floristería es:", flores)
if letrero == "sí":
 print("El letrero que tiene la floristería es:", t_letrero)
if graffiti == "sí":
 print("El graffiti que tiene la floristería es:", t_graffiti)

# %%
t_letrero=""
t_graffiti=""
color_techo=input("¿Cuál es el color del techo de tu escuela?")
color_pared_trasera=input("¿Cuál es el color de la pared trasera de tu escuela?")
color_pared_lado_derecho=input("¿Cuál es el color de la pared del lado derecho de tu escuela?")
color_pared_lado_izquierdo=input("¿Cuál es el color de la pared del lado izquierdo de tu escuela?")
cant_ventanas=int(input("¿Cuántas ventanas tiene tu escuela?"))
ventana_abierta=input("¿Tienes alguna ventana abierta?, (sí/no)")
if ventana_abierta == "sí":
  v_abierta="Abierta"
else:
  v_abierta="Cerrada"
cant_puertas=int(input("¿Cuántas puertas tiene tu escuela?"))
puerta_abierta=input("¿La puerta de tu escuela está abierta?, (sí/no)")
if puerta_abierta == "sí":
  p_abierta="Abierta"
else:
  p_abierta="Cerrada"
cant_pisos=int(input("¿Cuántos pisos tiene tu escuela?"))
cant_baños=int(input("¿Cuántos baños tiene tu escuela?"))
color_marco_ventanas=input("¿Tu escuela tiene color en el marco de las ventanas, (sí/no)?")
if color_marco_ventanas == "sí":
  color_m_ventanas=input("¿Cuál es el color del marco de tus ventanas?")
decoración_flores=input("¿Tu escuela tiene decoración de flores, (sí/no)?")
if decoración_flores == "sí":
  flores=input("¿Qué tipo de flores tiene?")
letrero=input("¿Tu floristería tiene letreros, (sí/no)?")
if letrero == "sí":
  t_letrero=input("¿Qué dice tu letrero?")
graffiti=input("¿Tu escuela tiene graffitis, (sí/no)?")
if graffiti == "sí":
  t_graffiti=input("¿Qué graffiti tiene tu escuela?")
cant_macetas=(input("¿ Tu escuela tiene macetas, (sí/no)?"))
if cant_macetas == "sí":
    c_macetas=input("¿Cuántas macetas hay en tu escuela?")
ubicación=input("¿En donde está ubicada tu escuela?")
cant_estantes=input("¿Tu escuela tiene estantes, (sí/no)?")
if cant_estantes =="sí":
  c_estantes=int(input("¿Cuántos estantes tiene tu escuela?"))
cant_salones=int(input("¿Cuántos salones tien tu escuela?"))
cant_profesores=int(input("¿Cuántos profesores tiene tu escuela ?"))
cant_alumnos=int(input("¿Cuántos alumnos tiene tu escuela?"))
cant_canchas=int(input("¿Cuántas canchas tiene tu escuela?"))
print("El color del techo de tu escuela es:", color_techo)
if cant_macetas == "sí":
 print("Tu escuela tiene,", c_macetas, "cantidad de macetas")
print("Tu escuela está ubicada en:", ubicación)


if cant_estantes =="sí":
  print("La cantidad de estantes de tu escuela es:", c_estantes)
print("El color de la pared trasera de la escuela es:", color_pared_trasera)
print("El color de la pared del lado derecho de tu escuela es:", color_pared_lado_derecho)
print("El color de la pared del lado izquierdo de tu escuela es:", color_pared_lado_izquierdo)
print("La cantidad de ventanas que tiene tu escuela es:", cant_ventanas)
print("La cantidad de salones tu de escuela es:",cant_salones)
print("La cantidad de profesores que tiene tu escuela es: ", cant_profesores)
print("La cantidad de alumnos que tiene tu escuela es: ", cant_alumnos)
print("Tu escuela tiene", cant_canchas,"cantidad de canchas")
if ventana_abierta == "sí":
  print("La ventana está: ", v_abierta)
else:
  print("La ventana está: ", v_abierta)
print("La cantidad de puertas que tiene tu escuela es:", cant_puertas)
if puerta_abierta == "sí":
  print("La puerta de tu escuela está:", p_abierta)
else:
  print("La puerta de tu escuela está:", p_abierta)
print("La cantidad de pisos que tiene tu escuela es:", cant_pisos)
print("La cantidad de baños que tiene tu escuela es:", cant_baños)
if color_marco_ventanas == "sí":
 print("El color del marco de las ventanas de  tu escuela es:", color_m_ventanas)
if decoración_flores == "sí":
 print("El tipo de flores que tiene tu escuela es:", flores)
if letrero == "sí":
 print("El letrero que tiene tu escuela es:", t_letrero)
if graffiti == "sí":
 print("El graffiti que tiene tu escuela es:", t_graffiti)
